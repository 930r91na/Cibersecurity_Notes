# %% [markdown]
# # Ellipctic Curve Cryptography
#
# E = y^2 = x^3 +ax +bmod p so it exists in the G(p)
#
#
# COndition to say that EC is non sigular
# 4a^3 +27 b^2 is not 0 mod p
#
#
#
# Example Given a E: y ^2 = x^3 +2x +2 mod 17 in Z17, p 017
# a is 2, b is 2
# 4(2)^3 +27 (2)^2 is not 0 mod 17 indeed is 4
#
# If given P is 5,1 and assumme P = Q
# You can calculte R with the below  equationas and get
# 2P = 6, 3
# Then you can replace with the equation

# %% [markdown]
# Point Addition
#
# given P and Q points in the elliptic curve
# P+Q = R
# To do so you must draw a line between P and Q and then the result is mirrored over x axis
#
# Point doubling
# P+P = 2P
# A tangent line through p and mirror in x axis
#
# Calculate slope
# s if P=Q
# s = 3x1^2 + a/ 2y1
# s if P is not Q
# s = (y2 - y1)/ x2-x1
#
# and to add the points you get x3 and y3
# x3  = s^2 - x1 -x2 mod p
# y2  = s(x1 -x3 ) -y1 mod p

# %% [markdown]
# ECDH
#
# Compute the symeetric key
# p Prime Number
# E elleptic curve
# P primitive point
# private key a, b
# Public key A = aP and B = bP
# Kab = aB = bA
#
#
# Alice
# Can choose a nP and it has options from  kperA = a existst 2 to #E -1
# Given kperA 3
# Then 3P  = (10,6) this is the public key for alice
#
# Bob
# Can choose a nP and it has options from  kperA = a existst 2 to #E -1
# Given kperA 5 - IT MUST NOT BE THE SAME AS ALICE
# Then 5  = (7, 11) - this is the Public key for bob
#
# Swap the Public keys
# for alice
# TAB = aB = 3(7,11) = 13, 10
# for bob
# TAB = bA = 10(10,6) = 13,10
#
# 1) Hybrid encryption
# use one of the point encryption  is used as input for the following symmetric encryption
#
#
# 2) Direct Encryption
# Alice Select P as her plain text
